# %%
from fastapi import FastAPI
import joblib
import pandas as pd

# %%
app = FastAPI()

model = joblib.load("fantasy_model.pkl")

@app.get("/predict")
def predict(player: str, week: int):
    features = get_features_for_player(player, week)
    pred = model.predict(features)
    return {"player": player, "projection": float(pred[0])}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1551880397.py in <cell line: 0>()
#       1 app = FastAPI()
#       2
# ----> 3 model = joblib.load("fantasy_model.pkl")
#       4
#       5 @app.get("/predict")
#
# /usr/local/lib/python3.12/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fantasy_model.pkl'

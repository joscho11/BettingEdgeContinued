# %%
import os
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/MyDrive/BEC/BettingEdgeContinued')

# Configure git
# !git config --global user.email "joseph.schoenbaum@gmail.com"
# !git config --global user.name "Joseph Schoenbaum"

# Add your file
# !git add sports_betting_agent.ipynb

# Commit
# !git commit -m "Add LLM sports betting agent"

# Push with token (replace YOUR_TOKEN)
# !git push https://YOUR_TOKEN@github.com/joscho11/BettingEdgeContinued.git main
# Out:
# [main 7644d69] Add LLM sports betting agent
#  1 file changed, 1 insertion(+)
#  create mode 100644 sports_betting_agent.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address
